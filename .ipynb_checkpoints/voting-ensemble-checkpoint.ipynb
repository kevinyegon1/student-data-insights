# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\hi\Desktop\Data Analytics\Data Sets\new\python_learning_exam_performance.csv")
df = df.dropna().reset_index()
df = df.drop(columns=['index'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1938 entries, 0 to 1937
# Data columns (total 15 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   student_id                         1938 non-null   int64
#  1   age                                1938 non-null   int64
#  2   country                            1938 non-null   object
#  3   prior_programming_experience       1938 non-null   object
#  4   weeks_in_course                    1938 non-null   int64
#  5   hours_spent_learning_per_week      1938 non-null   float64
#  6   practice_problems_solved           1938 non-null   int64
#  7   projects_completed                 1938 non-null   int64
#  8   tutorial_videos_watched            1938 non-null   int64
#  9   uses_kaggle                        1938 non-null   int64
#  10  participates_in_discussion_forums  1938 non-null   int64
# ...

# %%
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

# %%
y = df['passed_exam']
X = df.drop(columns=['student_id','final_exam_score','passed_exam'])

# %%
#identifying column types
num_col = X.select_dtypes('int64','float64').columns
cat_col = X.select_dtypes('object').columns

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25)

# %%
# preprocessing
preprocessing = ColumnTransformer(
    transformers=[
        ('num',StandardScaler(), num_col),
        ('cat',OneHotEncoder(handle_unknown='ignore'), cat_col)
    ]
)

# %%
# defining base models
rfc = RandomForestClassifier(random_state=42, n_estimators=100,class_weight='balanced') 

xgb = XGBClassifier(random_state=42)

# %%
# ensembling using votting classifier
ensemble = VotingClassifier(
    estimators=[('rf',rfc),('xgb',xgb)],
    voting='soft',
)

# %%
# imblearn pipeline
model = Pipeline(
    steps=[
        ('preprocessing',preprocessing),
        ('smote',SMOTE(random_state=42)),
        ('classifier', ensemble)
    ]
)

# %%
#model training and prediction
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['age', 'weeks_in_course', 'practice_problems_solved',
#        'projects_completed', 'tutorial_videos_watched', 'uses_kaggle',
#        'participates_in_discussion_forums', 'debugging_sessions_per_week',
#        'self_reported_confidence_python'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(han...
#                                                              grow_policy=None,
#                                                              importance_type=None,
#                                                              interaction_constraints=None,
#                                                              learning_rate=None,
#                                                              max_bin=None,
# ...

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       337
#            1       0.68      0.59      0.63       148
#
#     accuracy                           0.79       485
#    macro avg       0.75      0.73      0.74       485
# weighted avg       0.78      0.79      0.79       485

# %% [markdown]
# # tuning the parameters

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold

# 1. Define the Parameter Grid with correct 'double underscore' paths
# Syntax: [step_name]__[parameter] OR [step_name]__[model_name]__[parameter]
param_grid = {
    # Adjust the SMOTE ratio
    'smote__sampling_strategy': [0.7, 1.0],
    
    # Adjust the Ensemble voting type
    'classifier__voting': ['soft'], # Soft is usually better for probabilities
    
    # Tune the Random Forest inside the ensemble
    'classifier__rf__n_estimators': [100, 200],
    'classifier__rf__max_depth': [None, 10],
    
    # Tune the XGBoost inside the ensemble
    'classifier__xgb__learning_rate': [0.01, 0.1],
    'classifier__xgb__n_estimators': [100],
    
    # Balance the influence of RF vs XGB
    'classifier__weights': [[1, 1], [2, 1], [1, 2]]
}

# 2. Setup Cross-Validation
cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# 3. Initialize GridSearch
# We use 'f1' to balance Precision and Recall for the failing students
grid_search = GridSearchCV(
    estimator=model, 
    param_grid=param_grid, 
    cv=cv_strategy, 
    scoring='f1', 
    n_jobs=-1,
    verbose=1
)

# 4. Fit the model
grid_search.fit(X_train, y_train)

# 5. Output Results
print(f"Best Score (F1): {grid_search.best_score_:.4f}")
print("Best Parameters found:")
for param, value in grid_search.best_params_.items():
    print(f"{param}: {value}")
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# Best Score (F1): 0.6217
# Best Parameters found:
# classifier__rf__max_depth: 10
# classifier__rf__n_estimators: 100
# classifier__voting: soft
# classifier__weights: [1, 1]
# classifier__xgb__learning_rate: 0.1
# classifier__xgb__n_estimators: 100
# smote__sampling_strategy: 0.7

# %%
grid_search.best_estimator_.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['age', 'weeks_in_course', 'practice_problems_solved',
#        'projects_completed', 'tutorial_videos_watched', 'uses_kaggle',
#        'participates_in_discussion_forums', 'debugging_sessions_per_week',
#        'self_reported_confidence_python'],
#       dtype='object')),
#                                                  ('cat',
#                                                   OneHotEncoder(han...
#                                                              grow_policy=None,
#                                                              importance_type=None,
#                                                              interaction_constraints=None,
#                                                              learning_rate=0.1,
#                                                              max_bin=None,
# ...

# %%
y_prediction = grid_search.best_estimator_.predict(X_test)

# %%
print(classification_report(y_test, y_prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.88      0.86       337
#            1       0.69      0.62      0.65       148
#
#     accuracy                           0.80       485
#    macro avg       0.77      0.75      0.76       485
# weighted avg       0.80      0.80      0.80       485

# %%
# heatmap plot of confusion matrix
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cm = confusion_matrix(y_test, y_prediction)

plt.figure(figsize=(5,5))
sns.heatmap(cm,annot=True,xticklabels=['predicted 0','predicted 1'], yticklabels=['actual 0', 'actual 1'], fmt='d')
plt.title('Confusion Matrix Performance breakdown')
plt.xlabel('Predicted values')
plt.ylabel('Actual values')
plt.tight_layout()
plt.show()
